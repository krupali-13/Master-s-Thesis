# %% [markdown]
# # Load Data Preprocessing
#
# This notebook peformes the preprocessing of the load datasets

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ### Get CSV Data And Rename Columns

# %%
dff = pd.read_csv('../../0raw_data/2012-2013 Solar home electricity data.csv', header=1)
dff
# Out:
#         Customer  Generator Capacity  Postcode Consumption Category  \
# 0              1                3.78      2076                   CL
# 1              1                3.78      2076                   GC
# 2              1                3.78      2076                   GG
# 3              1                3.78      2076                   CL
# 4              1                3.78      2076                   GC
# ...          ...                 ...       ...                  ...
# 268552       300                3.36      2086                   GC
# 268553       300                3.36      2086                   GG
# 268554       300                3.36      2086                   CL
# 268555       300                3.36      2086                   GC
# 268556       300                3.36      2086                   GG
#
#               date   0:30   1:00   1:30   2:00   2:30  ...  20:00  20:30  \
# 0        1/07/2012  1.250  1.250  1.250  1.263  0.131  ...  0.000  0.000
# ...

# %%
#Import csv file with second row as header
dff = pd.read_csv('../../0raw_data/2012-2013 Solar home electricity data.csv', header=1)

#Change Date Format
dff.date = pd.to_datetime(dff.date, format='%d/%m/%Y')

#Rename columns to unique name
dff.rename(columns={
    '1:00':'01:00', '2:00':'02:00','3:00':'03:00','4:00':'04:00','5:00':'05:00',
    '1:30':'01:30', '2:30':'02:30','3:30':'03:30','4:30':'04:30','5:30':'05:30',
    '6:00':'06:00','7:00':'07:00','8:00':'08:00','9:00':'09:00', '0:00':'00:00',
    '6:30':'06:30','7:30':'07:30','8:30':'08:30','9:30':'09:30', '0:30':'00:30'
}, inplace=True)

#Only Consider hourly values
dff.drop([
    '00:30', '01:30', '02:30', '03:30', '04:30', '05:30', '06:30', '07:30', '08:30', '09:30',
    '10:30', '11:30', '12:30', '13:30', '14:30', '15:30', '16:30', '17:30', '18:30', '19:30',
    '20:30', '21:30', '22:30', '23:30', 'Row Quality'
], axis=1, inplace=True)

#Instead of 300 household only consider the first 30 (12% of 300)
def keep_first_percentage(df, percentage):
    num_rows = int(len(df) * percentage)  # Calculate the number of rows to keep

    # Keep the first 'num_rows' rows
    kept_df = df.head(num_rows)

    return kept_df
dff = keep_first_percentage(dff, percentage=0.12)

#Delete PV generation (GG - gross generation) and CL(controlled load)
dff = dff[(dff['Consumption Category'] != "GG") & (dff['Consumption Category'] != "CL")]

#Delete column Geneator capacity and Consumption category
dff.drop(['Generator Capacity', 'Consumption Category'], axis=1, inplace=True)

dff.head(12)
# Out:
#     Customer  Postcode       date  01:00  02:00  03:00  04:00  05:00  06:00  \
# 1          1      2076 2012-07-01  0.786  0.544  0.612  0.665  0.140  0.337
# 4          1      2076 2012-07-02  0.082  0.097  0.155  0.688  0.395  0.090
# 7          1      2076 2012-07-03  0.076  0.088  0.160  0.692  0.158  1.161
# 10         1      2076 2012-07-04  0.082  0.098  1.046  1.810  0.150  0.072
# 13         1      2076 2012-07-05  0.255  0.115  0.406  0.671  0.122  0.048
# 16         1      2076 2012-07-06  0.105  0.103  0.159  0.939  0.141  0.149
# 19         1      2076 2012-07-07  0.203  0.058  0.372  0.679  0.157  0.098
# 22         1      2076 2012-07-08  0.253  0.441  0.220  0.635  0.109  0.061
# 25         1      2076 2012-07-09  0.190  0.190  0.510  0.698  0.137  0.849
# 28         1      2076 2012-07-10  0.738  0.857  0.677  1.332  0.128  0.851
# 31         1      2076 2012-07-11  0.103  0.103  0.396  0.689  0.156  0.096
# ...

# %%
def expand_dataframe(df):
    expanded_df = pd.DataFrame(columns=['Date', 'User', 'Consumption_kW'])

    # Iterate over each row in the input dataframe
    for index, row in df.iterrows():
        date = row['date'].strftime("%Y-%m-%d")
        
        # Iterate over each time interval in the row
        for time_col in df.columns[3:]:
            date_time = "{} {}:00".format(date, time_col)
            meter_reading = row[time_col]
            user = "User{}".format(row['Customer'])
            new_df = pd.DataFrame(data=[[date_time, user, meter_reading]], columns=['Date', 'User', 'Consumption_kW'])
            expanded_df = pd.concat([expanded_df, new_df], ignore_index=True)   
      
    return expanded_df

df = expand_dataframe(dff)
print(df.columns)
print(df)
# Out:
# /var/folders/3t/xy996zrd62bgg6pzxysmz80h0000gn/T/ipykernel_30817/2148669808.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   expanded_df = pd.concat([expanded_df, new_df], ignore_index=True)
# Index(['Date', 'User', 'Consumption_kW'], dtype='object')
#                        Date    User  Consumption_kW
# 0       2012-07-01 01:00:00   User1           0.786
# 1       2012-07-01 02:00:00   User1           0.544
# 2       2012-07-01 03:00:00   User1           0.612
# 3       2012-07-01 04:00:00   User1           0.665
# 4       2012-07-01 05:00:00   User1           0.140
# ...                     ...     ...             ...
# 307435  2012-10-24 20:00:00  User36           0.138
# 307436  2012-10-24 21:00:00  User36           0.279
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Filter the DataFrame for 'User1' and select the first 300 rows
user1_data = df[df['User'] == 'User1'].head(100)

# Plot electricity consumption based on time
plt.figure(figsize=(10, 6))
plt.plot(user1_data['Date'], user1_data['Consumption_kW'], marker='o')

# Adding titles and labels
plt.title('Electricity Consumption Over Time for User1 (First 300 Rows)')
plt.xlabel('Time')
plt.ylabel('Electricity Consumption (kW)')
plt.xticks(rotation=45)
plt.grid(True)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Filter the DataFrame for 'User1' and select the first 300 rows
user1_data = df[df['User'] == 'User1'].head(300)

# Convert 'Date' column to datetime if it's not already
user1_data['Date'] = pd.to_datetime(user1_data['Date'])

# Sort the data by 'Date' to ensure the plot is chronological
user1_data = user1_data.sort_values(by='Date')

# Plot electricity consumption based on time
plt.figure(figsize=(10, 6))
plt.plot(user1_data['Date'], user1_data['Consumption_kW'])

# Adding titles and labels
plt.title('Electricity Consumption Over Time for User1 (First 300 Rows)')
plt.xlabel('Time')
plt.ylabel('Electricity Consumption (kW)')

# Format the x-axis to show month and year
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%Y'))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adding grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the data is loaded into a DataFrame called df
# Convert the 'Date' column to datetime format if it's not already
df['Date'] = pd.to_datetime(df['Date'])

# List the users you want to plot
users_to_plot = ['User1', 'User2', 'User3', 'User4']

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Flatten the axes array for easy iteration
axs = axs.flatten()

# Iterate over the selected users and their corresponding subplot axis
for i, user in enumerate(users_to_plot):
    # Filter the first 300 rows for the current user
    user_data = df[df['User'] == user].head(300)
    
    # Extract month names for the x-axis labels
    months = user_data['Date'].dt.strftime('%B')
    
    # Plot the data on the corresponding subplot axis
    axs[i].plot(months, user_data['Consumption_kW'], label=user)
    
    # Set the title for each subplot
    axs[i].set_title(f'Energy Consumption for {user}')
    
    # Set x and y labels
    axs[i].set_xlabel('Month')
    axs[i].set_ylabel('Energy Consumption (kW)')
    
    # Rotate x-axis labels for better readability
    axs[i].tick_params(axis='x', rotation=45)
    
    # Add a legend to each subplot
    axs[i].legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the data is loaded into a DataFrame called df
# List the users you want to plot
users_to_plot = ['User3', 'User9', 'User25', 'User31']

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Flatten the axes array for easy iteration
axs = axs.flatten()

# Iterate over the selected users and their corresponding subplot axis
for i, user in enumerate(users_to_plot):
    # Filter the first 300 rows for the current user
    user_data = df[df['User'] == user].head(300)
    
    # Plot the data on the corresponding subplot axis
    axs[i].plot(user_data['Date'], user_data['Consumption_kW'], label=user)
    
    # Set the title for each subplot
    axs[i].set_title(f'Energy Consumption for {user}')
    
    # Set x and y labels
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('Energy Consumption (kW)')
    
    # Rotate x-axis labels for better readability
    axs[i].tick_params(axis='x', rotation=45)
    
    # Add a legend to each subplot
    axs[i].legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and has 'Date' and 'User' columns
users_to_plot = ['User3', 'User9', 'User25', 'User31']

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 6))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Iterate over the users and their corresponding subplot axes
for ax, user in zip(axes, users_to_plot):
    user_data = df[df.User == user]['Consumption_kW'].resample('H').mean()  # Resample to hourly if needed
    user_data.plot(ax=ax)
    ax.set_title(f'{user} Data')
    ax.set_xlabel('Date')
    ax.set_ylabel('Consumption (kW)')
    ax.grid(True)  # Optional: Add grid for better readability

# Adjust layout
plt.tight_layout()

# Save the plot as a PDF
plt.savefig('electricity_consumption.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Koblenz/Summer Sem 2024/Master Thesis/Sec_FL_Attack/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 7
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Convert 'Date' column to datetime if it's not already
df['Date'] = pd.to_datetime(df['Date'])

# List of users to plot
users = ['User3', 'User9', 'User11', 'User25']

# Create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 7))

# Plot for each user
for i, user in enumerate(users):
    # Filter the data for the current user and select the first 300 rows
    user_data = df[df['User'] == user].head(300)
    
    # Sort the data by 'Date' to ensure the plot is chronological
    user_data = user_data.sort_values(by='Date')
    
    # Determine the position in the subplot grid
    ax = axs[i//2, i%2]
    
    # Plot electricity consumption based on time
    ax.plot(user_data['Date'], user_data['Consumption_kW'])
    
    # Set titles and labels
    ax.set_title(f'Electricity Consumption for {user}')
    ax.set_xlabel('Time')
    #ax.set_ylabel('Electricity Consumption (kW)')
    
    # Format the x-axis to show month and year
    ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%Y'))
    
    # Rotate x-axis labels for better readability
    ax.tick_params(axis='x', rotation=45)
    

# Adjust layout for better spacing
plt.tight_layout()

# Save the plot as a PDF
plt.savefig('electricity consumption.pdf', format='pdf')

# Display the plot
plt.show()

# %%
#Visualize examplary user
df[df.User == "User9"][:300].plot()
# Out:
# <Axes: >

# %%
# Find the starting index of each user's data
user_start_indices = df.groupby('User').apply(lambda x: x.index[0]).reset_index(name='Start_Index')
print(user_start_indices)
# Out:
#       User  Start_Index
# 0    User1            0
# 1   User10        76896
# 2   User11        85656
# 3   User12        94416
# 4   User13       103176
# 5   User14       111936
# 6   User15       120696
# 7   User16       129456
# 8   User17       138216
# 9   User18       146976
# 10  User19       155736
# 11   User2         8760
# 12  User20       164496
# 13  User21       173256
# 14  User22       182016
# 15  User23       190776
# 16  User24       199536
# 17  User25       208296
# 18  User26       217056
# 19  User27       225816
# 20  User28       234576
# 21  User29       243336
# 22   User3        15576
# 23  User30       252096
# 24  User31       260856
# 25  User32       269616
# 26  User33       278376
# 27  User34       287136
# 28  User35       295896
# 29  User36       304656
# 30   User4        24336
# 31   User5        33096
# 32   User6        41856
# 33   User7        50616
# 34   User8        59376
# 35   User9        68136

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and has a 'User' column
users_to_plot = ['User3', 'User9', 'User25', 'User31']

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 6))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Iterate over the users and their corresponding subplot axes
for ax, user in zip(axes, users_to_plot):
    user_data = df[df.User == user][:300]
    user_data.plot(ax=ax)
    ax.set_title(f'{user} Data')

# Adjust layout
plt.tight_layout()

# Save the plot as a PDF
plt.savefig('electricity consumption.pdf', format='pdf')

# Show the plot
plt.show()

# %%
#Display basic statistics for each User
#Exclude User9, User 19

df_check = df
for counter in range(1,30):
    print("-----------------------------------------", counter)
    dfNew = df_check[df_check.User == "User{}".format(counter)]
    display(dfNew.tail())
    display(dfNew.describe().T)

    dfNew= dfNew.replace(0.0, np.nan)
    null_percentage= dfNew.isnull().mean()*100
    print('Null values in each column in percentages:', null_percentage)
# Out:
# ----------------------------------------- 1
#                      Date   User  Consumption_kW
# 8755  2013-06-30 20:00:00  User1           0.213
# 8756  2013-06-30 21:00:00  User1           0.190
# 8757  2013-06-30 22:00:00  User1           0.274
# 8758  2013-06-30 23:00:00  User1           0.166
# 8759  2013-06-30 00:00:00  User1           0.631
#                  count      mean       std  min    25%    50%   75%    max
# Consumption_kW  8760.0  0.293394  0.298903  0.0  0.104  0.176  0.36  2.113
# Null values in each column in percentages: Date              0.000000
# User              0.000000
# Consumption_kW    0.045662
# dtype: float64
# ----------------------------------------- 2
#                       Date   User  Consumption_kW
# 15571  2013-06-30 20:00:00  User2           0.317
# 15572  2013-06-30 21:00:00  User2           0.224
# 15573  2013-06-30 22:00:00  User2           0.303
# 15574  2013-06-30 23:00:00  User2           0.158
# ...

# %%
# Pivot the dataframe
pivot_df = df.pivot(index='Date', columns='User', values='Consumption_kW').reset_index()

# Rename the columns
pivot_df.columns.name = None

load_final = pivot_df

# Print the resulting dataframe
load_final.head()
# Out:
#                   Date  User1  User10  User11  User12  User13  User14  User15  \
# 0  2012-07-01 00:00:00  0.068   0.703   0.353   0.210   0.138   0.208   0.065
# 1  2012-07-01 01:00:00  0.786   0.036   0.547   0.197   0.343   0.176   0.067
# 2  2012-07-01 02:00:00  0.544   0.045   0.519   0.163   0.339   0.164   0.057
# 3  2012-07-01 03:00:00  0.612   0.031   0.324   0.173   0.337   0.178   0.063
# 4  2012-07-01 04:00:00  0.665   0.018   0.343   0.156   0.363   0.193   0.065
#
#    User16  User17  ...  User33  User34  User35  User36  User4  User5  User6  \
# 0   0.340   0.129  ...   0.284   0.244   0.397   0.102  0.090  0.098  0.636
# 1   0.508   0.121  ...   0.661   0.331   0.276   0.077  0.084  0.098  0.253
# 2   0.542   0.141  ...   0.276   0.169   0.305   0.025  0.084  0.075  0.220
# 3   0.590   0.165  ...   0.293   0.169   0.304   0.036  0.091  0.072  0.241
# 4   0.551   0.122  ...   0.276   0.113   0.261   0.054  0.091  0.092  0.199
#
#    User7  User8  User9
# ...

# %%
#Save as CSV file
load_final.to_csv('../2012-2013 Load_preprocessed.csv', index=False)
